# %%
# Change your repo dir
repo_dir = '/kaggle/input/aic-video'
# %cd {repo_dir}
# Out:
# /kaggle/input/aic-video

# %%
# !pip install ffmpeg-python pillow
# !git clone https://github.com/soCzech/TransNetV2.git
# %cd /kaggle/input/transnet-v2/TransNetV2/inference
# Out:
# Requirement already satisfied: ffmpeg-python in /opt/conda/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (9.5.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from ffmpeg-python) (1.0.0)
# fatal: could not create work tree dir 'TransNetV2': Read-only file system
# /kaggle/input/transnet-v2/TransNetV2/inference

# %%
# Import module
import os
import cv2
import json
import glob
import ffmpeg
import torch
import numpy as np
from tqdm import tqdm
from transnetv2 import TransNetV2

# %%
videos_dir = '/kaggle/input/aic-video/AIC_Video'
all_video_paths = dict()
for part in sorted(os.listdir(videos_dir)):
    data_part = part.split('_')[-1] # L01, L02 for ex
    all_video_paths[data_part] =  dict()

for data_part in sorted(all_video_paths.keys()):
    data_part_path = f'{videos_dir}/Videos_{data_part}/video'
    video_paths = sorted(os.listdir(data_part_path))
    video_ids = [video_path.replace('.mp4', '').split('_')[-1] for video_path in video_paths]
    for video_id, video_path in zip(video_ids, video_paths):
        video_path_full = f'{data_part_path}/{video_path}'
        all_video_paths[data_part][video_id] = video_path_full

# %%
model = TransNetV2()

save_dir = '/kaggle/working/SceneJSON'
if not os.path.exists(save_dir):
    os.mkdir(save_dir)

for key, video_paths_dict in tqdm(all_video_paths.items()):
    if key == 'L05':
        video_ids = sorted(video_paths_dict.keys())

        if not os.path.exists(os.path.join(save_dir, key)):
            os.mkdir(os.path.join(save_dir, key))

        for video_id in tqdm(video_ids):
            video_path = video_paths_dict[video_id]
            _, single_frame_predictions, _ = model.predict_video(video_path)

            # Generate list of scenes from predictions, returns tuples of (start frame, end frame)
            scenes = model.predictions_to_scenes(single_frame_predictions)

            with open(f"{save_dir}/{key}/{video_id}.json", 'w') as f:
                json.dump(scenes.tolist(), f)
# Out:
# [TransNetV2] Using weights from /kaggle/input/transnet-v2/TransNetV2/inference/transnetv2-weights/.
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V001.mp4
# [TransNetV2] Processing video frames 29176/29176
#   3%|▎         | 1/31 [11:31<5:45:37, 691.24s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V002.mp4
# [TransNetV2] Processing video frames 27308/27308
#   6%|▋         | 2/31 [22:09<5:18:59, 659.99s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V003.mp4
# [TransNetV2] Processing video frames 29623/29623
#  10%|▉         | 3/31 [33:46<5:15:53, 676.92s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V004.mp4
# [TransNetV2] Processing video frames 27181/27181
#  13%|█▎        | 4/31 [44:26<4:58:02, 662.33s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V005.mp4
# [TransNetV2] Processing video frames 25942/25942
#  16%|█▌        | 5/31 [54:36<4:38:47, 643.37s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V006.mp4
# [TransNetV2] Processing video frames 33171/33171
#  19%|█▉        | 6/31 [1:07:37<4:47:33, 690.16s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V007.mp4
# [TransNetV2] Processing video frames 26134/26134
#  23%|██▎       | 7/31 [1:17:53<4:26:21, 665.89s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V008.mp4
# [TransNetV2] Processing video frames 32094/32094
#  26%|██▌       | 8/31 [1:30:23<4:25:31, 692.69s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V009.mp4
# [TransNetV2] Processing video frames 27944/27944
#  29%|██▉       | 9/31 [1:41:16<4:09:31, 680.53s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V010.mp4
# [TransNetV2] Processing video frames 25687/25687
#  32%|███▏      | 10/31 [1:51:13<3:49:08, 654.68s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V011.mp4
# [TransNetV2] Processing video frames 27239/27239
#  35%|███▌      | 11/31 [2:01:56<3:36:58, 650.93s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V012.mp4
# [TransNetV2] Processing video frames 28914/28914
#  39%|███▊      | 12/31 [2:13:20<3:29:20, 661.06s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V013.mp4
# [TransNetV2] Processing video frames 33960/33960
#  42%|████▏     | 13/31 [2:26:36<3:30:36, 702.03s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V014.mp4
# [TransNetV2] Processing video frames 27648/27648
#  45%|████▌     | 14/31 [2:37:27<3:14:32, 686.62s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V015.mp4
# [TransNetV2] Processing video frames 31247/31247
#  48%|████▊     | 15/31 [2:49:40<3:06:47, 700.49s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V016.mp4
# [TransNetV2] Processing video frames 29566/29566
#  52%|█████▏    | 16/31 [3:01:13<2:54:35, 698.37s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V017.mp4
# [TransNetV2] Processing video frames 29579/29579
#  55%|█████▍    | 17/31 [3:12:46<2:42:33, 696.67s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V018.mp4
# [TransNetV2] Processing video frames 28351/28351
#  58%|█████▊    | 18/31 [3:23:50<2:28:47, 686.77s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V019.mp4
# [TransNetV2] Processing video frames 29384/29384
#  61%|██████▏   | 19/31 [3:35:17<2:17:24, 687.02s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V020.mp4
# [TransNetV2] Processing video frames 27247/27247
#  65%|██████▍   | 20/31 [3:46:00<2:03:31, 673.79s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V021.mp4
# [TransNetV2] Processing video frames 23213/23213
#  68%|██████▊   | 21/31 [3:55:00<1:45:34, 633.42s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V022.mp4
# [TransNetV2] Processing video frames 30486/30486
#  71%|███████   | 22/31 [4:06:54<1:38:40, 657.85s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V023.mp4
# [TransNetV2] Processing video frames 30300/30300
#  74%|███████▍  | 23/31 [4:18:46<1:29:52, 674.03s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V024.mp4
# [TransNetV2] Processing video frames 30843/30843
#  77%|███████▋  | 24/31 [4:30:48<1:20:19, 688.51s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V025.mp4
# [TransNetV2] Processing video frames 26361/26361
#  81%|████████  | 25/31 [4:41:06<1:06:43, 667.32s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V026.mp4
# [TransNetV2] Processing video frames 25454/25454
#  84%|████████▍ | 26/31 [4:51:03<53:50, 646.09s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V027.mp4
# [TransNetV2] Processing video frames 28448/28448
#  87%|████████▋ | 27/31 [5:02:09<43:27, 651.96s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V028.mp4
# [TransNetV2] Processing video frames 27906/27906
#  90%|█████████ | 28/31 [5:13:13<32:47, 655.78s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V029.mp4
# [TransNetV2] Processing video frames 28321/28321
#  94%|█████████▎| 29/31 [5:24:20<21:58, 659.12s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V030.mp4
# [TransNetV2] Processing video frames 28823/28823
#  97%|█████████▋| 30/31 [5:35:41<11:05, 665.63s/it]
# [TransNetV2] Extracting frames from /kaggle/input/aic-video/AIC_Video/Videos_L05/video/L05_V031.mp4
# [TransNetV2] Processing video frames 35891/35891
# 100%|██████████| 31/31 [5:49:47<00:00, 677.01s/it]
# 100%|██████████| 12/12 [5:49:47<00:00, 1748.95s/it]
